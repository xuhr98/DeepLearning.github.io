# %%
import torch
import torch.nn.functional as F


x_data=torch.Tensor([[1.0],[2.],[3.]])
y_data=torch.Tensor([[0],[0],[1]])

# %%
class LogisticRegressionModel(torch.nn.Module):
    def __init__(self):
        super(LogisticRegressionModel,self).__init__()
        self.linear=torch.nn.Linear(1,1)
    
    def forward(self,x):
        y_pred=F.sigmoid(self.linear(x))
        return y_pred
model=LogisticRegressionModel()

# %%
criterion=torch.nn.BCELoss(reduction='sum') #求交叉熵
optimizer=torch.optim.SGD(model.parameters(),lr=0.01)

# %%
for epoch in range(100):
    y_pred=model(x_data)
    loss=criterion(y_pred,y_data)
    print('epoch=%d,loss=%f' %(epoch,loss.item()))
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
# Out:
# epoch=0,loss=2.703113
# epoch=1,loss=2.647718
# epoch=2,loss=2.594589
# epoch=3,loss=2.543708
# epoch=4,loss=2.495053
# epoch=5,loss=2.448596
# epoch=6,loss=2.404304
# epoch=7,loss=2.362135
# epoch=8,loss=2.322045
# epoch=9,loss=2.283985
# epoch=10,loss=2.247899
# epoch=11,loss=2.213731
# epoch=12,loss=2.181418
# epoch=13,loss=2.150896
# epoch=14,loss=2.122098
# epoch=15,loss=2.094957
# epoch=16,loss=2.069402
# epoch=17,loss=2.045364
# epoch=18,loss=2.022772
# epoch=19,loss=2.001555
# epoch=20,loss=1.981644
# epoch=21,loss=1.962970
# epoch=22,loss=1.945467
# epoch=23,loss=1.929068
# epoch=24,loss=1.913710
# epoch=25,loss=1.899331
# epoch=26,loss=1.885871
# epoch=27,loss=1.873273
# epoch=28,loss=1.861483
# epoch=29,loss=1.850449
# epoch=30,loss=1.840119
# epoch=31,loss=1.830448
# epoch=32,loss=1.821391
# epoch=33,loss=1.812906
# epoch=34,loss=1.804952
# epoch=35,loss=1.797492
# epoch=36,loss=1.790491
# epoch=37,loss=1.783917
# epoch=38,loss=1.777737
# epoch=39,loss=1.771924
# epoch=40,loss=1.766450
# epoch=41,loss=1.761290
# epoch=42,loss=1.756421
# epoch=43,loss=1.751821
# epoch=44,loss=1.747470
# epoch=45,loss=1.743349
# epoch=46,loss=1.739440
# epoch=47,loss=1.735728
# epoch=48,loss=1.732197
# epoch=49,loss=1.728834
# epoch=50,loss=1.725625
# epoch=51,loss=1.722559
# epoch=52,loss=1.719625
# epoch=53,loss=1.716812
# epoch=54,loss=1.714112
# epoch=55,loss=1.711515
# epoch=56,loss=1.709014
# epoch=57,loss=1.706601
# epoch=58,loss=1.704269
# epoch=59,loss=1.702013
# epoch=60,loss=1.699826
# epoch=61,loss=1.697702
# epoch=62,loss=1.695638
# epoch=63,loss=1.693629
# epoch=64,loss=1.691670
# epoch=65,loss=1.689758
# epoch=66,loss=1.687888
# epoch=67,loss=1.686059
# epoch=68,loss=1.684266
# epoch=69,loss=1.682508
# epoch=70,loss=1.680780
# epoch=71,loss=1.679082
# epoch=72,loss=1.677411
# epoch=73,loss=1.675765
# epoch=74,loss=1.674143
# epoch=75,loss=1.672541
# epoch=76,loss=1.670960
# epoch=77,loss=1.669397
# epoch=78,loss=1.667851
# epoch=79,loss=1.666322
# epoch=80,loss=1.664807
# epoch=81,loss=1.663307
# epoch=82,loss=1.661819
# epoch=83,loss=1.660343
# epoch=84,loss=1.658879
# epoch=85,loss=1.657425
# epoch=86,loss=1.655982
# epoch=87,loss=1.654547
# epoch=88,loss=1.653122
# epoch=89,loss=1.651704
# epoch=90,loss=1.650295
# epoch=91,loss=1.648892
# epoch=92,loss=1.647496
# epoch=93,loss=1.646107
# epoch=94,loss=1.644725
# epoch=95,loss=1.643348
# epoch=96,loss=1.641976
# epoch=97,loss=1.640610
# epoch=98,loss=1.639248
# epoch=99,loss=1.637892
